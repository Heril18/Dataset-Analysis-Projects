# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("Pokemon.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df['Name'][df.Speed==df.Speed.max()]
# Out:
# 431    DeoxysSpeed Forme
# Name: Name, dtype: object

# %%
df[df.Speed==df.Speed.max()]
# Out:
#        #               Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 431  386  DeoxysSpeed Forme  Psychic    NaN    600  50      95       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 431       95       90    180           3       True

# %%
df.loc[431]['#']
# Out:
# 386

# %%
df.iloc[431]['Name']
# Out:
# 'DeoxysSpeed Forme'

# %%
display(df.loc[(df.Legendary=='True') & (df.HP>100)])
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
df[df.HP==df.HP.max()]
# Out:
#        #     Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261  242  Blissey  Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# 261      135     55           2      False

# %%
p=df[(df.Legendary==True) | (df.HP>100)]
p.shape
# Out:
# (114, 13)

# %%
df[df['Type 1']=='Dragon']
# Out:
#        #                     Name  Type 1    Type 2  Total   HP  Attack  \
# 159  147                  Dratini  Dragon       NaN    300   41      64
# 160  148                Dragonair  Dragon       NaN    420   61      84
# 161  149                Dragonite  Dragon    Flying    600   91     134
# 365  334                  Altaria  Dragon    Flying    490   75      70
# 366  334      AltariaMega Altaria  Dragon     Fairy    590   75     110
# 406  371                    Bagon  Dragon       NaN    300   45      75
# 407  372                  Shelgon  Dragon       NaN    420   65      95
# 408  373                Salamence  Dragon    Flying    600   95     135
# 409  373  SalamenceMega Salamence  Dragon    Flying    700   95     145
# 417  380                   Latias  Dragon   Psychic    600   80      80
# 418  380        LatiasMega Latias  Dragon   Psychic    700   80     100
# 419  381                   Latios  Dragon   Psychic    600   80      90
# ...

# %%
df.loc[df['Type 1']=="Fire"]
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
df['Name'][df.Total==df.Total.max()]
# Out:
# 163      MewtwoMega Mewtwo X
# 164      MewtwoMega Mewtwo Y
# 426    RayquazaMega Rayquaza
# Name: Name, dtype: object

# %%
df['Total'][df.Total==df.Total.max()]
# Out:
# 163    780
# 164    780
# 426    780
# Name: Total, dtype: int64

# %%
df.sort_values(['Total'],ascending=False)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# ..   ...                    ...      ...       ...    ...  ...     ...
# 13    10               Caterpie      Bug       NaN    195   45      30
# 288  265                Wurmple      Bug       NaN    195   45      45
# 446  401              Kricketot      Bug       NaN    194   37      25
# 322  298                Azurill   Normal     Fairy    190   50      20
# 206  191                Sunkern    Grass       NaN    180   30      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
p=df[(df.Legendary==True) & ((df['Type 1']=='Dragon') | (df['Type 2']=='Dragon'))]
p
# Out:
#        #                   Name  Type 1    Type 2  Total   HP  Attack  \
# 417  380                 Latias  Dragon   Psychic    600   80      80
# 418  380      LatiasMega Latias  Dragon   Psychic    700   80     100
# 419  381                 Latios  Dragon   Psychic    600   80      90
# 420  381      LatiosMega Latios  Dragon   Psychic    700   80     130
# 425  384               Rayquaza  Dragon    Flying    680  105     150
# 426  384  RayquazaMega Rayquaza  Dragon    Flying    780  105     180
# 540  483                 Dialga   Steel    Dragon    680  100     120
# 541  484                 Palkia   Water    Dragon    680   90     120
# 544  487  GiratinaAltered Forme   Ghost    Dragon    680  150     100
# 545  487   GiratinaOrigin Forme   Ghost    Dragon    680  150     120
# 706  643               Reshiram  Dragon      Fire    680  100     120
# 707  644                 Zekrom  Dragon  Electric    680  100     150
# ...

# %%
df[df.Total==df.Total.max()]
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      100      154      100    130           1       True
# 164       70      194      120    140           1       True
# 426      100      180      100    115           3       True

# %%
plt.grid()
p=df[250:265]
l=plt.bar(p.index,p.HP, color ='yellow',width = 0.4)
l
# Out:
# <BarContainer object of 15 artists>

# %%
plt.grid()
p=df[df.HP>150]
plt.bar(p.HP,p.index)
# Out:
# <BarContainer object of 6 artists>

# %%
df.sort_values(['HP','Total'],ascending=(0,1))
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
# ..   ...        ...      ...    ...    ...  ...     ...      ...      ...
# 388  355    Duskull    Ghost    NaN    295   20      40       90       30
# 487  439   Mime Jr.  Psychic  Fairy    310   20      25       45       70
# 230  213    Shuckle      Bug   Rock    505   20      10      230       10
# 55    50    Diglett   Ground    NaN    265   10      55       25       35
# 316  292   Shedinja      Bug  Ghost    236    1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
print(df.shape[0])
df['Heril']=df['Defense']+df['Sp. Def']
df
# Out:
# 800
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
col=list(df.columns)
df=df[[col[-1]]+col[0:13]]

# %%
df
# Out:
#      Heril    #                   Name   Type 1  Type 2  Total  HP  Attack  \
# 0      114    1              Bulbasaur    Grass  Poison    318  45      49
# 1      143    2                Ivysaur    Grass  Poison    405  60      62
# 2      183    3               Venusaur    Grass  Poison    525  80      82
# 3      243    3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4       93    4             Charmander     Fire     NaN    309  39      52
# ..     ...  ...                    ...      ...     ...    ...  ..     ...
# 795    300  719                Diancie     Rock   Fairy    600  50     100
# 796    220  719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797    190  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798    190  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799    210  721              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.to_csv("Modified_Pokemon.csv",index=False)
df.to_excel("Modified_Pokemon.xlsx")

# %%
import re
df.loc[df["Name"].str.contains('fire|grass',flags=re.I,regex=True)]
# Out:
# Empty DataFrame
# Columns: [Heril, #, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
import re
df.loc[df["Name"].str.contains('fire|grass',flags=re.I,regex=True)]
df
# Out:
#      Heril    #                   Name   Type 1  Type 2  Total  HP  Attack  \
# 0      114    1              Bulbasaur    Grass  Poison    318  45      49
# 1      143    2                Ivysaur    Grass  Poison    405  60      62
# 2      183    3               Venusaur    Grass  Poison    525  80      82
# 3      243    3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4       93    4             Charmander     Fire     NaN    309  39      52
# ..     ...  ...                    ...      ...     ...    ...  ..     ...
# 795    300  719                Diancie     Rock   Fairy    600  50     100
# 796    220  719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797    190  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798    190  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799    210  721              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Type 1']=='Fire','Type 1']="Flame"
df
# Out:
#      Heril    #                   Name   Type 1  Type 2  Total  HP  Attack  \
# 0      114    1              Bulbasaur    Grass  Poison    318  45      49
# 1      143    2                Ivysaur    Grass  Poison    405  60      62
# 2      183    3               Venusaur    Grass  Poison    525  80      82
# 3      243    3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4       93    4             Charmander    Flame     NaN    309  39      52
# ..     ...  ...                    ...      ...     ...    ...  ..     ...
# 795    300  719                Diancie     Rock   Fairy    600  50     100
# 796    220  719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797    190  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798    190  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799    210  721              Volcanion    Flame   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df.Total>500,['Generation','Legendary']]=['Test1','Test2']
df
# Out:
#      Heril    #                   Name   Type 1  Type 2  Total  HP  Attack  \
# 0      114    1              Bulbasaur    Grass  Poison    318  45      49
# 1      143    2                Ivysaur    Grass  Poison    405  60      62
# 2      183    3               Venusaur    Grass  Poison    525  80      82
# 3      243    3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4       93    4             Charmander    Flame     NaN    309  39      52
# ..     ...  ...                    ...      ...     ...    ...  ..     ...
# 795    300  719                Diancie     Rock   Fairy    600  50     100
# 796    220  719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797    190  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798    190  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799    210  721              Volcanion    Flame   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed Generation Legendary
# ...

# %%
df.groupby(['Type 2']).mean().sort_values('Attack',ascending=False)
# Out:
#                Heril           #       Total         HP      Attack  \
# Type 2
# Fighting  164.884615  438.192308  525.846154  79.461538  112.846154
# Dark      141.900000  413.850000  484.400000  75.550000  109.800000
# Ice       170.428571  441.285714  525.714286  90.000000   98.000000
# Dragon    170.500000  482.555556  526.166667  82.166667   94.444444
# Steel     190.909091  435.636364  485.227273  64.636364   92.590909
# Bug       141.666667  382.000000  393.333333  53.333333   90.000000
# Ground    157.057143  307.600000  444.342857  77.228571   89.857143
# Ghost     160.357143  551.714286  430.714286  59.142857   84.142857
# Rock      195.428571  347.785714  434.642857  68.071429   84.000000
# Fire      163.666667  481.833333  506.250000  71.250000   81.250000
# Flying    139.515464  331.103093  452.546392  71.391753   80.288660
# Psychic   174.636364  337.151515  479.060606  72.212121   74.696970
# Grass     154.640000  505.400000  408.920000  62.640000   74.160000
# ...

# %%
df['count']=1
p=(df.groupby(['Type 1','Type 2']).sum())
p.count()
# Out:
# Heril      136
# #          136
# Total      136
# HP         136
# Attack     136
# Defense    136
# Sp. Atk    136
# Sp. Def    136
# Speed      136
# count      136
# dtype: int64

# %%
df['Type 2'].isnull().sum()
386+414
# Out:
# 800

# %%
for df in pd.read_csv("Pokemon.csv",chunksize=5):
    results=df.groupby('Type 1').count()
    newdf=
# Out:
# Chunk Data
#         #  Name  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Fire    1     1       0      1   1       1        1        1        1      1
# Grass   4     4       4      4   4       4        4        4        4      4
#
#         Generation  Legendary
# Type 1
# Fire             1          1
# Grass            4          4   Chunk Data
#         #  Name  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Fire    4     4       3      4   4       4        4        4        4      4
# Water   1     1       0      1   1       1        1        1        1      1
#
#         Generation  Legendary
# Type 1
# Fire             4          4
# Water            1          1   Chunk Data
#         #  Name  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug     2     2       0      2   2       2        2        2        2      2
# Water   3     3       0      3   3       3        3        3        3      3
# ...
